# %% [markdown]
# ### Antes de correr este archivo, asegúrate de tener todos los datasets del atributo y confirmar que están bien construidos.
#
# Este archivo notebook deja preparada una plantilla con todas las instrucciones para entrenar cada modelo de clasificación. En este caso, la técnica de interés ha sido {func}.
# Cada celda comprende un modelo de clasificación. La idea de trabajarlo en notebook es que, de quererlo, puedas hacer más exploraciones e indagaciones del modelo resultante.
#
# Los atributos de interés son:
# * object.modelo: permite utilizar el objeto de sklearn para predecir.
# * self.train_set y self.test_set: lista con división de variables X e Y. La posición 0 corresponde a los datos de entrada; 1, a los de salida.
# * self.train_report y self.test_report: para observar los resultados de precisión.

# %%
import QoL as qol
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### K-Nearest Neighbors

# %% [markdown]
# 1. Cargar los datos de la técnica al entrenador. Se hace también una revisión de los datos corruptos en el dataset y la cantidad de letras con la que se cuenta.

# %%
knn = qol.model_trainer(tecnica='graph',modelo='knn')
knn.class_counts()
# Out:
# ----- Sumilla de errores -----
#
# Se han encontrado 25 errores de lectura en train y 2 en test. Borrando.
# Se han encontrado 235 filas corruptas en train y 7 en test. Borrando.
# Se han encontrado 8 filas con letras mal posicionadas en train y 0 en test. Borrando.
#
# ------------------------------
#     Letra  En train  En test
# 0       A       845       97
# 1       B       801       96
# 2   Blank       813      100
# 3       C       801       99
# 4       D       805      100
# 5       E       780       99
# 6       F       802       97
# 7       G       796       96
# 8       H       848       97
# 9       I       808       98
# 10      J       813       97
# 11      K       792       93
# 12      L       781       99
# 13      M       805      100
# 14      N       776       96
# 15      O       849       98
# 16      P       798      100
# 17      Q       799       95
# 18      R       836       99
# 19      S       826       95
# 20      T       817       93
# 21      U       800       99
# 22      V       808      100
# 23      W       801       97
# 24      X       811       96
# 25      Y       824       97
# 26      Z       863      100

# %%
# %%time
knn.train_model()
knn.generate_error_reports()
knn.export_model()
knn.modelo
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# CPU times: total: 953 ms
# Wall time: 23.7 s
# KNeighborsClassifier(metric='manhattan', n_neighbors=10, weights='distance')

# %% [markdown]
# Acá saldrán unos mensajes de excepciones, probablemente, debido a los multiprocesos que hace sklearn. No es nada de qué preocuparse, salvo genere ya un error de ejecución.
#
# Listo, modelo creado.

# %% [markdown]
# ### Random Forest

# %% [markdown]
# 1. Cargar los datos de la técnica al entrenador. Se hace también una revisión de los datos corruptos en el dataset y la cantidad de letras con la que se cuenta.

# %%
rf = qol.model_trainer(tecnica='graph',modelo='rf')
rf.class_counts()
# Out:
# ----- Sumilla de errores -----
#
# Se han encontrado 25 errores de lectura en train y 2 en test. Borrando.
# Se han encontrado 235 filas corruptas en train y 7 en test. Borrando.
# Se han encontrado 8 filas con letras mal posicionadas en train y 0 en test. Borrando.
#
# ------------------------------
#     Letra  En train  En test
# 0       A       845       97
# 1       B       801       96
# 2   Blank       813      100
# 3       C       801       99
# 4       D       805      100
# 5       E       780       99
# 6       F       802       97
# 7       G       796       96
# 8       H       848       97
# 9       I       808       98
# 10      J       813       97
# 11      K       792       93
# 12      L       781       99
# 13      M       805      100
# 14      N       776       96
# 15      O       849       98
# 16      P       798      100
# 17      Q       799       95
# 18      R       836       99
# 19      S       826       95
# 20      T       817       93
# 21      U       800       99
# 22      V       808      100
# 23      W       801       97
# 24      X       811       96
# 25      Y       824       97
# 26      Z       863      100

# %%
# %%time
rf.train_model()
rf.generate_error_reports()
rf.export_model()
rf.modelo
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# CPU times: total: 953 ms
# Wall time: 23.7 s
# KNeighborsClassifier(metric='manhattan', n_neighbors=10, weights='distance')

# %% [markdown]
# Acá saldrán unos mensajes de excepciones, probablemente, debido a los multiprocesos que hace sklearn. No es nada de qué preocuparse, salvo genere ya un error de ejecución.
#
# Listo, modelo creado.

# %% [markdown]
# ### Artificial Neural Network

# %% [markdown]
# 1. Cargar los datos de la técnica al entrenador. Se hace también una revisión de los datos corruptos en el dataset y la cantidad de letras con la que se cuenta.

# %%
ann = qol.model_trainer(tecnica='graph',modelo='ann')
ann.class_counts()
# Out:
# ----- Sumilla de errores -----
#
# Se han encontrado 25 errores de lectura en train y 2 en test. Borrando.
# Se han encontrado 235 filas corruptas en train y 7 en test. Borrando.
# Se han encontrado 8 filas con letras mal posicionadas en train y 0 en test. Borrando.
#
# ------------------------------
#     Letra  En train  En test
# 0       A       845       97
# 1       B       801       96
# 2   Blank       813      100
# 3       C       801       99
# 4       D       805      100
# 5       E       780       99
# 6       F       802       97
# 7       G       796       96
# 8       H       848       97
# 9       I       808       98
# 10      J       813       97
# 11      K       792       93
# 12      L       781       99
# 13      M       805      100
# 14      N       776       96
# 15      O       849       98
# 16      P       798      100
# 17      Q       799       95
# 18      R       836       99
# 19      S       826       95
# 20      T       817       93
# 21      U       800       99
# 22      V       808      100
# 23      W       801       97
# 24      X       811       96
# 25      Y       824       97
# 26      Z       863      100

# %%
# %%time
ann.train_model()
ann.generate_error_reports()
ann.export_model()
ann.modelo
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# CPU times: total: 953 ms
# Wall time: 23.7 s
# KNeighborsClassifier(metric='manhattan', n_neighbors=10, weights='distance')

# %% [markdown]
# Acá saldrán unos mensajes de excepciones, probablemente, debido a los multiprocesos que hace sklearn. No es nada de qué preocuparse, salvo genere ya un error de ejecución.
#
# Listo, modelo creado.
