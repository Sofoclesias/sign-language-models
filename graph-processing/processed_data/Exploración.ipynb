# %%
import QOL_funcs as qol
import warnings
warnings.filterwarnings("ignore")

# %%
image = r'C:\Users\PC\Documents\GitHub Repos\sign-language-models\synthetic-asl-alphabet\Test_Alphabet\A\0de66b7e-1449-4079-bf2c-935ec261ddcb.rgb_0000.png'
qol.mediapipe_landmarks(image,vis=True,app=False)
